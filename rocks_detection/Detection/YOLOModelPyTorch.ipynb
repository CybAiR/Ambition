# %%
import os
import cv2
import torch
from ultralytics import YOLO

#os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

if __name__ == '__main__':
    torch.cuda.empty_cache()

    model = YOLO('yolov8n.pt')

    model.train(
        data=r'D:\Studia\cybAIR\Ambition\rocks_detection\Detection\data.yaml',
        epochs=50,
        imgsz=640,
        batch=8,
        workers=2,
        project='depthai_model',
        name='yolo_rocks_btr',
        exist_ok=True
    )

    best_model = YOLO('depthai_model/yolo_rocks_btr/weights/best.pt')

    path = "./TestImages/"
    for filename in os.listdir(path):
        if filename.startswith("4"):
            img_path = os.path.join(path, filename)
            results = best_model.predict(source=img_path, conf=0.70)
            img = cv2.imread(img_path)
            for box in results[0].boxes:
                x1, y1, x2, y2 = map(int, box.xyxy[0])
                cv2.rectangle(img, (x1, y1), (x2, y2), (0, 255, 0), 2, cv2.LINE_AA)
            cv2.imshow("YOLO Detekcja", img)
            cv2.waitKey(0)
            break

    cv2.destroyAllWindows()
# Out:
# New https://pypi.org/project/ultralytics/8.4.60 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.52  Python-3.10.11 torch-2.7.1+cu118 CUDA:0 (GeForce GTX 1650 Ti, 4096MiB)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=8, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=D:\Studia\cybAIR\Ambition\rocks_detection\Detection\data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=50, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=yolo_rocks, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=depthai_model, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=D:\Studia\cybAIR\Ambition\rocks_detection\Detection\runs\detect\depthai_model\yolo_rocks, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=2, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751507  ultralytics.nn.modules.head.Detect           [1, 16, None, [64, 128, 256]]
# Model summary: 130 layers, 3,011,043 parameters, 3,011,027 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# WARNING AMP: checks failed . AMP training on GeForce GTX 1650 Ti GPU may cause NaN losses or zero-mAP results, so AMP will be disabled during training.
# train: Fast image access  (ping: 0.10.0 ms, read: 1671.2844.6 MB/s, size: 5963.0 KB)
# train: Scanning D:\Studia\cybAIR\Ambition\rocks_detection\Detection\train\labels.cache... 494 images, 83 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 494/494  0.0s
# train: D:\Studia\cybAIR\Ambition\rocks_detection\Detection\train\images\20260601_171447_jpg.rf.qYdwPzUkRO5VPoo7mVF0.jpg: corrupt JPEG restored and saved
# train: D:\Studia\cybAIR\Ambition\rocks_detection\Detection\train\images\20260601_171449_jpg.rf.SyeO1cPAHt5fn9BOERNc.jpg: corrupt JPEG restored and saved
# train: D:\Studia\cybAIR\Ambition\rocks_detection\Detection\train\images\20260601_171451_jpg.rf.8XVFdICIa6GUlMCf4Rar.jpg: corrupt JPEG restored and saved
# train: D:\Studia\cybAIR\Ambition\rocks_detection\Detection\train\images\20260601_171453_jpg.rf.p22qS2v6tB98OIQW6rUZ.jpg: corrupt JPEG restored and saved
# train: D:\Studia\cybAIR\Ambition\rocks_detection\Detection\train\images\20260601_171454_jpg.rf.MgXH4XFiYjjkADasN81V.jpg: corrupt JPEG restored and saved
# train: D:\Studia\cybAIR\Ambition\rocks_detection\Detection\train\images\20260601_171456_jpg.rf.Uz56mw6trAeOteO58YyI.jpg: corrupt JPEG restored and saved
# train: D:\Studia\cybAIR\Ambition\rocks_detection\Detection\train\images\20260601_171457_jpg.rf.wn0OT1Cpt4xKKdeziV2R.jpg: corrupt JPEG restored and saved
# train: D:\Studia\cybAIR\Ambition\rocks_detection\Detection\train\images\20260601_171458_jpg.rf.Z9k9e7Q96J2QKhOm2k6Q.jpg: corrupt JPEG restored and saved
# train: D:\Studia\cybAIR\Ambition\rocks_detection\Detection\train\images\20260601_171501_jpg.rf.fRwYsBwDcjgmb024g80V.jpg: corrupt JPEG restored and saved
# train: D:\Studia\cybAIR\Ambition\rocks_detection\Detection\train\images\20260601_171505_jpg.rf.3hOra7UtH7xbMbW1RriR.jpg: corrupt JPEG restored and saved
# train: D:\Studia\cybAIR\Ambition\rocks_detection\Detection\train\images\20260601_171508_jpg.rf.vCngtBu1R0HZVXae35g8.jpg: corrupt JPEG restored and saved
# train: D:\Studia\cybAIR\Ambition\rocks_detection\Detection\train\images\20260601_171511_jpg.rf.twIoVrN30GsYHMBpxywX.jpg: corrupt JPEG restored and saved
# train: D:\Studia\cybAIR\Ambition\rocks_detection\Detection\train\images\20260601_171513_jpg.rf.bRYKMhEWOMwjizKBmVcv.jpg: corrupt JPEG restored and saved
# train: D:\Studia\cybAIR\Ambition\rocks_detection\Detection\train\images\20260601_171516_jpg.rf.fmBw4loaFzPpouRgwnNK.jpg: corrupt JPEG restored and saved
# train: D:\Studia\cybAIR\Ambition\rocks_detection\Detection\train\images\20260601_171519_jpg.rf.p1b4kuRJEhas5KdErpxH.jpg: corrupt JPEG restored and saved
# train: D:\Studia\cybAIR\Ambition\rocks_detection\Detection\train\images\20260601_171521_jpg.rf.eY2KjSeRA2bflCyuL7uo.jpg: corrupt JPEG restored and saved
# train: D:\Studia\cybAIR\Ambition\rocks_detection\Detection\train\images\20260601_171557_jpg.rf.fdi6SatFp7UE5gzL3OCh.jpg: corrupt JPEG restored and saved
# train: D:\Studia\cybAIR\Ambition\rocks_detection\Detection\train\images\20260601_171559_jpg.rf.hyGPTMiw9Twc9o8WZrkN.jpg: corrupt JPEG restored and saved
# train: D:\Studia\cybAIR\Ambition\rocks_detection\Detection\train\images\20260601_171600_jpg.rf.0vG81sctc5zy3fR0lNTu.jpg: corrupt JPEG restored and saved
# train: D:\Studia\cybAIR\Ambition\rocks_detection\Detection\train\images\20260601_171603_jpg.rf.WqDf4hVn6lDbOclqQN42.jpg: corrupt JPEG restored and saved
# train: D:\Studia\cybAIR\Ambition\rocks_detection\Detection\train\images\20260601_171607_jpg.rf.9IdrPSAbxoZOBRMvdu7z.jpg: corrupt JPEG restored and saved
# train: D:\Studia\cybAIR\Ambition\rocks_detection\Detection\train\images\20260601_171611_jpg.rf.iRhCYt7xuZWSlxZnnz5j.jpg: corrupt JPEG restored and saved
# train: D:\Studia\cybAIR\Ambition\rocks_detection\Detection\train\images\20260601_171613_jpg.rf.NpRn6DslkDsLxgWdA2iD.jpg: corrupt JPEG restored and saved
# train: D:\Studia\cybAIR\Ambition\rocks_detection\Detection\train\images\20260601_171616_jpg.rf.k9Af7KhSq4HlPyVYNZUN.jpg: corrupt JPEG restored and saved
# train: D:\Studia\cybAIR\Ambition\rocks_detection\Detection\train\images\20260601_171643_jpg.rf.TcXfieoVfYw9rwnW0rze.jpg: corrupt JPEG restored and saved
# train: D:\Studia\cybAIR\Ambition\rocks_detection\Detection\train\images\20260601_
6s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 6.3it/s 1.0s0.2s
#                    all         94       1962      0.776      0.657      0.731      0.452
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50      2.14G      1.087     0.8288     0.8957          6        640: 100% ━━━━━━━━━━━━ 62/62 1.8it/s 33.9s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 6.3it/s 1.0s0.2s
#                    all         94       1962      0.776       0.65      0.726       0.45
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50      1.96G      1.066     0.7811     0.8908          6        640: 100% ━━━━━━━━━━━━ 62/62 1.9it/s 33.0s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 6.7it/s 0.9s0.2s
#                    all         94       1962      0.769      0.637      0.716       0.45
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      2.12G       1.07     0.7728     0.8955          6        640: 100% ━━━━━━━━━━━━ 62/62 1.9it/s 33.5s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 6.3it/s 1.0s0.2s
#                    all         94       1962      0.778      0.653      0.728      0.457
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      2.12G      1.079     0.7501     0.8838          6        640: 100% ━━━━━━━━━━━━ 62/62 1.9it/s 32.5s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 6.5it/s 0.9s0.2s
#                    all         94       1962      0.774      0.646      0.724      0.458
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      2.15G       1.08      0.726     0.8752          6        640: 100% ━━━━━━━━━━━━ 62/62 1.8it/s 33.6s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.9it/s 1.0s0.2s
#                    all         94       1962      0.777      0.647      0.723      0.457
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      2.02G      1.054     0.7548     0.8851          6        640: 100% ━━━━━━━━━━━━ 62/62 1.8it/s 33.6s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 6.3it/s 1.0s0.2s
#                    all         94       1962      0.768      0.662      0.732       0.46
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      2.11G      1.063     0.7377     0.8735          6        640: 100% ━━━━━━━━━━━━ 62/62 1.9it/s 33.4s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.9it/s 1.0s0.2s
#                    all         94       1962      0.781      0.646      0.728      0.462
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      2.09G      1.014     0.7237     0.8817          6        640: 100% ━━━━━━━━━━━━ 62/62 1.8it/s 34.0s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 6.4it/s 0.9s0.2s
#                    all         94       1962      0.784       0.65      0.729      0.465
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      2.11G      1.032     0.7218     0.8746          6        640: 100% ━━━━━━━━━━━━ 62/62 1.8it/s 33.9s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 6.3it/s 1.0s0.2s
#                    all         94       1962       0.78      0.653      0.732      0.465
#
# 50 epochs completed in 0.534 hours.
# Optimizer stripped from D:\Studia\cybAIR\Ambition\rocks_detection\Detection\runs\detect\depthai_model\yolo_rocks\weights\last.pt, 6.2MB
# Optimizer stripped from D:\Studia\cybAIR\Ambition\rocks_detection\Detection\runs\detect\depthai_model\yolo_rocks\weights\best.pt, 6.2MB
#
# Validating D:\Studia\cybAIR\Ambition\rocks_detection\Detection\runs\detect\depthai_model\yolo_rocks\weights\best.pt...
# Ultralytics 8.4.52  Python-3.10.11 torch-2.7.1+cu118 CUDA:0 (GeForce GTX 1650 Ti, 4096MiB)
# Model summary (fused): 73 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.6it/s 2.3s0.3s
#                    all         94       1962      0.792      0.649      0.734      0.467
# Speed: 0.3ms preprocess, 4.5ms inference, 0.0ms loss, 8.0ms postprocess per image
# Results saved to D:\Studia\cybAIR\Ambition\rocks_detection\Detection\runs\detect\depthai_model\yolo_rocks
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 24
#      11 model = YOLO('yolov8n.pt')
#      13 model.train(
#      14     data=r'D:\Studia\cybAIR\Ambition\rocks_detection\Detection\data.yaml',
#      15     epochs=50,
#    (...)
#      21     exist_ok=True
#      22 )
# ---> 24 best_model = YOLO('depthai_model/yolo_rocks_NEW/weights/best.pt')
#      26 path = "./TestImages/"
#      27 for filename in os.listdir(path):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\models\yolo\model.py:77, in YOLO.__init__(self, model, task, verbose)
#      74     self.__dict__ = new_instance.__dict__
#      75 else:
#      76     # Continue with default YOLO initialization
# ---> 77     super().__init__(model=model, task=task, verbose=verbose)
#      78     if hasattr(self.model, "model") and "RTDETR" in self.model.model[-1]._get_name():  # if RTDETR head
#      79         from ultralytics import RTDETR
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\engine\model.py:144, in Model.__init__(self, model, task, verbose)
#     142     self._new(model, task=task, verbose=verbose)
#     143 else:
# --> 144     self._load(model, task=task)
#     146 # Delete super().training for accessing self.model.training
#     147 del self.training
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\engine\model.py:283, in Model._load(self, weights, task)
#     280 weights = checks.check_model_file_from_stem(weights)  # add suffix, i.e. yolo26 -> yolo26n.pt
#     282 if str(weights).rpartition(".")[-1] == "pt":
# --> 283     self.model, self.ckpt = load_checkpoint(weights)
#     284     self.task = self.model.task
#     285     self.overrides = self.model.args = self._reset_ckpt_args(self.model.args)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\nn\tasks.py:1615, in load_checkpoint(weight, device, inplace, fuse)
#    1613 if str(weight).lower().startswith(REMOTE_FILE_PREFIXES):
#    1614     weight = check_file(weight, download_dir=SETTINGS["weights_dir"])
# -> 1615 ckpt, weight = torch_safe_load(weight)  # load ckpt
#    1616 args = {**DEFAULT_CFG_DICT, **(ckpt.get("train_args", {}))}  # combine model and default args, preferring model args
#    1617 model = (ckpt.get("ema") or ckpt["model"]).float()  # FP32 model
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\nn\tasks.py:1544, in torch_safe_load(weight, safe_only)
#    1541         return torch_load(file, map_location="cpu")
#    1543 try:
# -> 1544     ckpt = _load()
#    1546 except RuntimeError as e:
#    1547     # Corrupt downloaded weight (e.g. truncated); skip user-supplied local paths to avoid destructive unlink.
#    1548     if "PytorchStreamReader" not in str(e) or Path(str(weight)).exists():
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\nn\tasks.py:1541, in torch_safe_load.<locals>._load()
#    1539     with open(file, "rb") as f:
#    1540         return torch_load(f, pickle_module=safe_pickle)
# -> 1541 return torch_load(file, map_location="cpu")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\utils\patches.py:181, in torch_load(*args, **kwargs)
#     178 if TORCH_1_13 and "weights_only" not in kwargs:
#     179     kwargs["weights_only"] = False
# --> 181 return torch.load(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\serialization.py:1479, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1476 if "encoding" not in pickle_load_args.keys():
#    1477     pickle_load_args["encoding"] = "utf-8"
# -> 1479 with _open_file_like(f, "rb") as opened_file:
#    1480     if _is_zipfile(opened_file):
#    1481         # The zipfile reader is going to advance the current file position.
#    1482         # If we want to actually tail call to torch.jit.load, we need to
#    1483         # reset back to the original position.
#    1484         orig_position = opened_file.tell()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\serialization.py:759, in _open_file_like(name_or_buffer, mode)
#     757 def _open_file_like(name_or_buffer: FileLike, mode: str) -> _opener[IO[bytes]]:
#     758     if _is_path(name_or_buffer):
# --> 759         return _open_file(name_or_buffer, mode)
#     760     else:
#     761         if "w" in mode:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\serialization.py:740, in _open_file.__init__(self, name, mode)
#     739 def __init__(self, name: Union[str, os.PathLike[str]], mode: str) -> None:
# --> 740     super().__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'depthai_model\\yolo_rocks_NEW\\weights\\best.pt'
